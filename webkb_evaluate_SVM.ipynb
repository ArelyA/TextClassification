# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import numpy as np
os.sys.path.insert(0, os.path.join('/content/gdrive/My Drive/libraries/naive_bayes_vectorizer/'))
os.sys.path.insert(0, os.path.join('/content/gdrive/My Drive/libraries/utils/'))
os.sys.path.insert(0, os.path.join('/content/gdrive/My Drive/libraries/svm/'))
from utils import split, evaluate, save_distances, evaluateSVM
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nb_vectorizer import GaussianNB
from naive_bayes_vectorizer import ComplementNB
from svc import SVC
from scipy.spatial import distance

classes = ['course', 'faculty', 'project', 'student']

currentFolder ='/content/gdrive/My Drive/'
c = [1.0, 10.0, 100.0, 1000.0, 10000.0, 100000.0]
kernel = ["linear", "poly", "rbf", "sigmoid"]

# %%
from joblib import dump, load
def classesSVM(c, kernel, vect, currentFolder):
  for k in kernel:
    for i in c:
      filename = currentFolder + "models/" + vect + '-' + k + "-" + str(i)
      clf = load(filename + '.joblib')
      print(clf.classes_)

# %%
# To get Counts
Count_x = CountVectorizer(max_features=75000)

# To vectorize
TFIDF_x = TfidfVectorizer(max_features=75000)
VectGaussian_NB = GaussianNB()
VectComplement_NB = ComplementNB()

# %%
dataset_test = open('/content/gdrive/My Drive/Datasets/webkb-test-stemmed.txt').read().split('\n')
dataset_train = open('/content/gdrive/My Drive/Datasets/webkb-train-stemmed.txt').read().split('\n')

X_train, y_train = split(dataset_train)
X_test, y_test = split(dataset_test)
# Out:
# ( 2803 1738 )
# ( 1396 49 )

# %%
#TFIDF
X_trainT = TFIDF_x.fit_transform(X_train).toarray()
X_testT = TFIDF_x.transform(X_test).toarray()

print(X_trainT.shape)
print(X_testT.shape)
# Out:
# (2803, 7287)
# (1396, 7287)

# %%
#evaluate evaluateSVM(X, y, c, kernel, vect, currentFolder)
evaluateSVM(X_testT, y_test, c, kernel, "T", currentFolder)
# Out:
# linear	0.910458452722063	0.8868194842406877	0.8732091690544412	0.8732091690544412	0.8732091690544412	0.8732091690544412	poly	0.6640401146131805	0.663323782234957	0.5515759312320917	0.5487106017191977	0.5487106017191977	0.5487106017191977	rbf	0.8846704871060171	0.8904011461318052	0.8904011461318052	0.8904011461318052	0.8904011461318052	0.8904011461318052	sigmoid	0.9061604584527221	0.8703438395415473	0.829512893982808	0.828080229226361	0.828080229226361	0.828080229226361

# %%
X_train = Count_x.fit_transform(X_train).toarray()
X_test = Count_x.transform(X_test).toarray()

print(X_train.shape)
print(X_test.shape)
# Out:
# (2803, 7287)
# (1396, 7287)

# %%
#Gaussian
X_trainG = VectGaussian_NB.fit_transform(X_train, y_train)
X_testG = VectGaussian_NB.transform(X_test)

print("(", len(X_trainG), len(X_trainG[0]), ")")
print("(", len(X_testG), len(X_testG[0]), ")")
# Out:
# ( 2803 4 )
# ( 1396 4 )

# %%
#evaluate evaluateSVM(X, y, c, kernel, vect, currentFolder)
evaluateSVM(X_testG, y_test, c, kernel, "G", currentFolder)
# Out:
# linear	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	poly	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	rbf	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	sigmoid	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605	0.5902578796561605

# %%
#Complement
X_trainC = VectComplement_NB.fit_transform(X_train, y_train)
X_testC = VectComplement_NB.transform(X_test)

X_trainC = np.around(X_trainC, decimals=5)
X_testC = np.around(X_testC, decimals=5)

print("(", len(X_trainC), len(X_trainC[0]), ")")
print("(", len(X_testC), len(X_testC[0]), ")")
# Out:
# ( 2803 4 )
# ( 1396 4 )

# %%
#evaluate evaluateSVM(X, y, c, kernel, vect, currentFolder)
evaluateSVM(X_testC, y_test, c, kernel, "C", currentFolder)
# Out:
# linear	0.8252148997134671	0.8252148997134671	0.8252148997134671	0.8252148997134671	0.8273638968481375	0.8259312320916905	poly	0.4326647564469914	0.46060171919770776	0.501432664756447	0.5479942693409742	0.589541547277937	0.6411174785100286	rbf	0.660458452722063	0.7851002865329513	0.8216332378223495	0.8209169054441261	0.8252148997134671	0.828080229226361	sigmoid	0.6117478510028653	0.7371060171919771	0.7492836676217765	0.7320916905444126	0.6755014326647565	0.6747851002865329
